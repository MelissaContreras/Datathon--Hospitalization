# %% [markdown]
# # <center> **Análisis de la Duración de Estancia hospitalaria** </center>
#
# ## <center> *Machine Learning* </center>

# %% [markdown]
# #### <center> En este proyecto con el análisis de datos vamos a implementar un modelo de *Machine Learning* con el cual realizaremos la predicción sobre la estancia hospitalaria </center>

# %% [markdown]
# #### Importamos las librerías necesarias.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Esta es la descripción de las dimensiones que recibimos
#
# - ***Available Extra Rooms in Hospital:*** Habitaciones adicionales disponibles en el hospital. Una habitación no es igual a un paciente, pueden ser individuales o compartidas.
# - ***Department:*** Área de atención a la que ingresa el paciente.
# - ***Ward_Facility_Code:*** Código de la habitación del paciente.
# - ***doctor_name:*** Nombre de el/la doctor/a a cargo del paciente.
# - ***staff_available:*** Cantidad de personal disponible al momento del ingreso del paciente.
# - ***patientid:*** Identificador del paciente.
# - ***Age:*** Edad del paciente.
# - ***gender:*** Género del paciente.
# - ***Type of Admission:*** Tipo de ingreso registrado según la situación de ingreso del paciente.
# - ***Severity of Illness:*** Gravedad de la enfermedad/condición/estado del paciente al momento del ingreso.
# - ***health_conditions:*** Condiciones de salud del paciente.
# - ***Visitors with Patient:*** Cantidad de visitantes registrados para el paciente.
# - ***Insurance:*** Indica si la persona posee o no seguro de salud.
# - ***Admission_Deposit:*** Pago realizado a nombre del paciente, con el fin de cubrir los costos iniciales de internación.
# - ***Stay (in days):*** Días registrados de estancia hospitalaria.​

# %% [markdown]
# ##### La librería pandas para leer los archivos. Observó las columnas del documento con .head().

# %%
DF = pd.read_csv("https://raw.githubusercontent.com/MelissaContreras/Datathon-1/main/hospitalizaciones_train.csv")
DF.head()
# Out:
#    Available Extra Rooms in Hospital  Department Ward_Facility_Code  \
# 0                                  4  gynecology                  D
# 1                                  4  gynecology                  B
# 2                                  2  gynecology                  B
# 3                                  4  gynecology                  D
# 4                                  2  anesthesia                  E
#
#   doctor_name  staff_available  patientid    Age  gender Type of Admission  \
# 0   Dr Sophia                0      33070  41-50  Female            Trauma
# 1   Dr Sophia                2      34808  31-40  Female            Trauma
# 2   Dr Sophia                8      44577  21-30  Female            Trauma
# 3   Dr Olivia                7       3695  31-40  Female            Urgent
# 4     Dr Mark               10     108956  71-80    Male            Trauma
#
#   Severity of Illness health_conditions  Visitors with Patient Insurance  \
# 0             Extreme          Diabetes                      4       Yes
# 1               Minor     Heart disease                      2        No
# 2             Extreme          Diabetes                      2       Yes
# 3            Moderate              None                      4        No
# 4            Moderate          Diabetes                      2        No
#
#    Admission_Deposit  Stay (in days)
# 0        2966.408696               8
# 1        3554.835677               9
# 2        5624.733654               7
# 3        4814.149231               8
# 4        5169.269637              34

# %% [markdown]
# #### Analizo sí hay datos faltantes.

# %%
DF.isnull().sum()
# Out:
# Available Extra Rooms in Hospital    0
# Department                           0
# Ward_Facility_Code                   0
# doctor_name                          0
# staff_available                      0
# patientid                            0
# Age                                  0
# gender                               0
# Type of Admission                    0
# Severity of Illness                  0
# health_conditions                    0
# Visitors with Patient                0
# Insurance                            0
# Admission_Deposit                    0
# Stay (in days)                       0
# dtype: int64

# %% [markdown]
# #### Dropeo las columnas que no aportan información relevante para determinar sí la estancia del paciente será larga o corta ( se considera corta hasta los 8 días de internación).

# %%
DF2 = DF.drop(['Ward_Facility_Code', 'doctor_name', 'patientid', 'Visitors with Patient', 'gender', 'Admission_Deposit'], axis=1)
DF2.head()
# Out:
#    Available Extra Rooms in Hospital  Department  staff_available    Age  \
# 0                                  4  gynecology                0  41-50
# 1                                  4  gynecology                2  31-40
# 2                                  2  gynecology                8  21-30
# 3                                  4  gynecology                7  31-40
# 4                                  2  anesthesia               10  71-80
#
#   Type of Admission Severity of Illness health_conditions Insurance  \
# 0            Trauma             Extreme          Diabetes       Yes
# 1            Trauma               Minor     Heart disease        No
# 2            Trauma             Extreme          Diabetes       Yes
# 3            Urgent            Moderate              None        No
# 4            Trauma            Moderate          Diabetes        No
#
#    Stay (in days)
# 0               8
# 1               9
# 2               7
# 3               8
# 4              34

# %% [markdown]
# #### **Reviso cuántas características hay por columna en las variables categóricas, es decir, variables no numéricas.**
# ##### Las variables categóricas pueden ser de dos tipos:
# ##### - **Variables ordinales:** sus valores pueden ser ordenados jerárquicamente, como las columnas de "Type of Admission" y "Severity of Illness", ya que tienen grado de intensidad sus     características.
# ##### - **Variables nominales:** no se puede establecer un orden en sus categorías, como en las columnas "Department" y "health_conditions".

# %%
DF2["Department"].unique()
# Out:
# array(['gynecology', 'anesthesia', 'TB & Chest disease', 'radiotherapy',
#        'surgery'], dtype=object)

# %%
DF2["Type of Admission"].unique()
# Out:
# array(['Trauma', 'Urgent', 'Emergency'], dtype=object)

# %%
DF2["Severity of Illness"].unique()
# Out:
# array(['Extreme', 'Minor', 'Moderate'], dtype=object)

# %%
DF2["health_conditions"].unique()
# Out:
# array(['Diabetes', 'Heart disease', 'None', 'Other', 'Asthama',
#        'High Blood Pressure'], dtype=object)

# %% [markdown]
# #### Transformo los datos de la columna que es nuestra variable de salida "Stay (in days)" con **pd.cut** a sistema binario y los guardo en "length of stay". Siendo "0" equivalente a estancia corta (8 días como máximo) y "1" es equivalente a estancia larga (desde 9 dias en adelante), para poder ingestar el modelo de clasificación.

# %%
DF2['length of stay'] = pd.cut(x = DF2['Stay (in days)'],
bins=[DF2['Stay (in days)'].min()-1,
8,
DF2['Stay (in days)'].max()+1], 
labels=['0', '1'])

# %%
DF2
# Out:
#         Available Extra Rooms in Hospital  Department  staff_available    Age  \
# 0                                       4  gynecology                0  41-50
# 1                                       4  gynecology                2  31-40
# 2                                       2  gynecology                8  21-30
# 3                                       4  gynecology                7  31-40
# 4                                       2  anesthesia               10  71-80
# ...                                   ...         ...              ...    ...
# 409995                                  1  gynecology                1  31-40
# 409996                                  5  gynecology                5  21-30
# 409997                                  4  gynecology                9  21-30
# 409998                                 10  gynecology               10  21-30
# 409999                                  3  gynecology                0  41-50
#
#        Type of Admission Severity of Illness health_conditions Insurance  \
# 0                 Trauma             Extreme          Diabetes       Yes
# 1                 Trauma               Minor     Heart disease        No
# 2                 Trauma             Extreme          Diabetes       Yes
# 3                 Urgent            Moderate              None        No
# 4                 Trauma            Moderate          Diabetes        No
# ...                  ...                 ...               ...       ...
# 409995            Trauma               Minor           Asthama       Yes
# 409996            Trauma             Extreme             Other        No
# 409997         Emergency               Minor           Asthama       Yes
# 409998            Trauma            Moderate             Other       Yes
# 409999            Trauma               Minor             Other       Yes
#
#         Stay (in days) length of stay
# 0                    8              0
# 1                    9              1
# 2                    7              0
# 3                    8              0
# 4                   34              1
# ...                ...            ...
# 409995               8              0
# 409996               9              1
# 409997               9              1
# 409998               9              1
# 409999               8              0
#
# [410000 rows x 10 columns]

# %% [markdown]
# ### **Gestión de características categóricas:**
# #### Es decir transformar estos datos a números ya que un modelo de Machine Learning sólo trabaja con números.
# #### Con **LabelEncoder()** para las categóricas nominales y **OrdinalEncoder()** para las categóricas ordinales.

# %%
# Instanciar LabelEncoder()

LabelEn = LabelEncoder()

DF2["Department"] = LabelEn.fit_transform(DF2["Department"])

# %%
DF2["Age"] = LabelEn.fit_transform(DF2["Age"])

# %%
# Creamos el codificador indicandole el orden jerárquico de la variables
encoder = OrdinalEncoder(categories=[['Urgent', 'Trauma','Emergency']])

# Entrenamos el codificador con la variable "Type of Admission" y la transformamos.
encoder.fit(DF2[["Type of Admission"]])
DF2["Type of Admission"] = encoder.transform(DF2[["Type of Admission"]])

# %%
# Creamos el codificador indicandole el orden jerárquico de la variables
encoder1 = OrdinalEncoder(categories=[['Minor', 'Moderate', 'Extreme']])

# Entrenamos el codificador con la variable "Severity of Illness" y la transformamos.
encoder1.fit(DF2[["Severity of Illness"]])
DF2["Severity of Illness"] = encoder1.transform(DF2[["Severity of Illness"]])

# %%
DF2["health_conditions"] = LabelEn.fit_transform(DF2["health_conditions"])

# %%
DF2["Insurance"] = LabelEn.fit_transform(DF2["Insurance"])

# %%
DF2
# Out:
#         Available Extra Rooms in Hospital  Department  staff_available  Age  \
# 0                                       4           2                0    4
# 1                                       4           2                2    3
# 2                                       2           2                8    2
# 3                                       4           2                7    3
# 4                                       2           1               10    7
# ...                                   ...         ...              ...  ...
# 409995                                  1           2                1    3
# 409996                                  5           2                5    2
# 409997                                  4           2                9    2
# 409998                                 10           2               10    2
# 409999                                  3           2                0    4
#
#         Type of Admission  Severity of Illness  health_conditions  Insurance  \
# 0                     1.0                  2.0                  1          1
# 1                     1.0                  0.0                  2          0
# 2                     1.0                  2.0                  1          1
# 3                     0.0                  1.0                  4          0
# 4                     1.0                  1.0                  1          0
# ...                   ...                  ...                ...        ...
# 409995                1.0                  0.0                  0          1
# 409996                1.0                  2.0                  5          0
# 409997                2.0                  0.0                  0          1
# 409998                1.0                  1.0                  5          1
# 409999                1.0                  0.0                  5          1
#
#         Stay (in days) length of stay
# 0                    8              0
# 1                    9              1
# 2                    7              0
# 3                    8              0
# 4                   34              1
# ...                ...            ...
# 409995               8              0
# 409996               9              1
# 409997               9              1
# 409998               9              1
# 409999               8              0
#
# [410000 rows x 10 columns]

# %% [markdown]
# #### Observamos la Correlación de las columnas una vez tranformadas en datos numéricos
# #### Se busca ver que variables guardan mayor correlación con la variable de salida.

# %%
DF2.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17760\3164217445.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   DF2.corr()
#                                    Available Extra Rooms in Hospital  \
# Available Extra Rooms in Hospital                           1.000000
# Department                                                 -0.021235
# staff_available                                            -0.003064
# Age                                                        -0.029921
# Type of Admission                                          -0.020866
# Severity of Illness                                        -0.037610
# health_conditions                                           0.001643
# Insurance                                                   0.002438
# Stay (in days)                                             -0.019383
#
#                                    Department  staff_available       Age  \
# Available Extra Rooms in Hospital   -0.021235        -0.003064 -0.029921
# Department                           1.000000         0.016304  0.013096
# staff_available                      0.016304         1.000000  0.001818
# Age                                  0.013096         0.001818  1.000000
# Type of Admission                    0.037395         0.002255 -0.005304
# Severity of Illness                  0.006407         0.001793  0.051760
# health_conditions                   -0.000344        -0.001500  0.037140
# Insurance                           -0.000714         0.001245 -0.002472
# Stay (in days)                      -0.204050         0.006673  0.585201
#
#                                    Type of Admission  Severity of Illness  \
# Available Extra Rooms in Hospital          -0.020866            -0.037610
# Department                                  0.037395             0.006407
# staff_available                             0.002255             0.001793
# Age                                        -0.005304             0.051760
# Type of Admission                           1.000000            -0.056357
# Severity of Illness                        -0.056357             1.000000
# health_conditions                          -0.001768            -0.145060
# Insurance                                   0.002062            -0.002555
# Stay (in days)                             -0.035811             0.055916
#
#                                    health_conditions  Insurance  \
# Available Extra Rooms in Hospital           0.001643   0.002438
# Department                                 -0.000344  -0.000714
# staff_available                            -0.001500   0.001245
# Age                                         0.037140  -0.002472
# Type of Admission                          -0.001768   0.002062
# Severity of Illness                        -0.145060  -0.002555
# health_conditions                           1.000000   0.008702
# Insurance                                   0.008702   1.000000
# Stay (in days)                              0.001772  -0.000947
#
#                                    Stay (in days)
# Available Extra Rooms in Hospital       -0.019383
# Department                              -0.204050
# staff_available                          0.006673
# Age                                      0.585201
# Type of Admission                       -0.035811
# Severity of Illness                      0.055916
# health_conditions                        0.001772
# Insurance                               -0.000947
# Stay (in days)                           1.000000

# %% [markdown]
# #### Observamos la relación de los datos gráficamente, para ver claramente que datos aportan de manera determinante a la variable de salida.

# %%
#Pairplot
sns.pairplot(DF2, hue="Stay (in days)", palette = "gist_earth")

# %%
# Heatmap
corr = DF2.corr(method="pearson")
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot = True, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        cmap= "coolwarm");
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18264\3504236683.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = DF2.corr(method="pearson")

# %% [markdown]
# #### Realizamos los mismos cambios en nuestro documento de Testeo. Ya que las variables en el modelo deben ser las mismas que con las que fue entrenada y así obtendremos la precicción que buscamos.

# %%
DFT = pd.read_csv("https://raw.githubusercontent.com/MelissaContreras/Datathon-1/main/hospitalizaciones_test.csv")
DFT
# Out:
#        Available Extra Rooms in Hospital          Department  \
# 0                                      3          gynecology
# 1                                      2  TB & Chest disease
# 2                                      2        radiotherapy
# 3                                      2          gynecology
# 4                                      2          anesthesia
# ...                                  ...                 ...
# 89995                                  4          gynecology
# 89996                                 13          gynecology
# 89997                                  2          gynecology
# 89998                                  2        radiotherapy
# 89999                                  3          gynecology
#
#       Ward_Facility_Code doctor_name  staff_available  patientid    Age  \
# 0                      F   Dr Olivia               10       2858  21-30
# 1                      E     Dr John                4      65657  51-60
# 2                      E     Dr John                7      45598  51-60
# 3                      F   Dr Olivia                1      31132  21-30
# 4                      A     Dr John                7     125021  51-60
# ...                  ...         ...              ...        ...    ...
# 89995                  F    Dr Sarah                2      43001  11-20
# 89996                  F   Dr Olivia                8      85601  31-40
# 89997                  B    Dr Sarah                3      22447  11-20
# 89998                  A     Dr John                1      29957  61-70
# 89999                  F   Dr Sophia                3      45008  41-50
#
#        gender Type of Admission Severity of Illness    health_conditions  \
# 0      Female            Trauma            Moderate                Other
# 1      Female            Trauma            Moderate              Asthama
# 2       Other            Trauma            Moderate                 None
# 3      Female            Trauma            Moderate                 None
# 4      Female            Trauma             Extreme             Diabetes
# ...       ...               ...                 ...                  ...
# 89995  Female            Trauma               Minor  High Blood Pressure
# 89996  Female         Emergency            Moderate                Other
# 89997  Female         Emergency            Moderate  High Blood Pressure
# 89998  Female            Trauma             Extreme             Diabetes
# 89999  Female            Trauma            Moderate        Heart disease
#
#        Visitors with Patient Insurance  Admission_Deposit
# 0                          2        No        4749.640225
# 1                          2       Yes        4122.261324
# 2                          3        No        5459.067882
# 3                          2       Yes        3987.033318
# 4                          2        No        4770.789695
# ...                      ...       ...                ...
# 89995                      3        No        4105.795901
# 89996                      2        No        4631.550257
# 89997                      2        No        5456.930075
# 89998                      2        No        4694.127772
# 89999                      4       Yes        4713.868519
#
# [90000 rows x 14 columns]

# %%
DFT.isnull().sum()
# Out:
# Available Extra Rooms in Hospital    0
# Department                           0
# Ward_Facility_Code                   0
# doctor_name                          0
# staff_available                      0
# patientid                            0
# Age                                  0
# gender                               0
# Type of Admission                    0
# Severity of Illness                  0
# health_conditions                    0
# Visitors with Patient                0
# Insurance                            0
# Admission_Deposit                    0
# dtype: int64

# %%
DFT2 = DFT.drop(['Ward_Facility_Code', 'doctor_name', 'patientid', 'Visitors with Patient', 'gender', 'Admission_Deposit'], axis=1)
DFT2.head()
# Out:
#    Available Extra Rooms in Hospital          Department  staff_available  \
# 0                                  3          gynecology               10
# 1                                  2  TB & Chest disease                4
# 2                                  2        radiotherapy                7
# 3                                  2          gynecology                1
# 4                                  2          anesthesia                7
#
#      Age Type of Admission Severity of Illness health_conditions Insurance
# 0  21-30            Trauma            Moderate             Other        No
# 1  51-60            Trauma            Moderate           Asthama       Yes
# 2  51-60            Trauma            Moderate              None        No
# 3  21-30            Trauma            Moderate              None       Yes
# 4  51-60            Trauma             Extreme          Diabetes        No

# %%
DFT2["Department"] = LabelEn.fit_transform(DFT2["Department"])

# %%
DFT2["Age"] = LabelEn.fit_transform(DFT2["Age"])

# %%
# Creamos el codificador indicandole el orden de la variables
encoder = OrdinalEncoder(categories=[['Urgent', 'Trauma','Emergency']])

# Entrenamos el codificador con la variable Type of Admission y la transformamos
encoder.fit(DFT2[["Type of Admission"]])
DFT2["Type of Admission"] = encoder.transform(DFT2[["Type of Admission"]])

# %%
# Creamos el codificador indicandole el orden de la variables
encoder1 = OrdinalEncoder(categories=[['Minor', 'Moderate', 'Extreme']])

# Entrenamos el codificador con la variable "Severity of Illness" y la transformamos
encoder1.fit(DFT2[["Severity of Illness"]])
DFT2["Severity of Illness"] = encoder1.transform(DFT2[["Severity of Illness"]])

# %%
DFT2["health_conditions"] = LabelEn.fit_transform(DFT2["health_conditions"])

# %%
DFT2["Insurance"] = LabelEn.fit_transform(DFT2["Insurance"])

# %%
DFT2
# Out:
#        Available Extra Rooms in Hospital  Department  staff_available  Age  \
# 0                                      3           2               10    2
# 1                                      2           0                4    5
# 2                                      2           3                7    5
# 3                                      2           2                1    2
# 4                                      2           1                7    5
# ...                                  ...         ...              ...  ...
# 89995                                  4           2                2    1
# 89996                                 13           2                8    3
# 89997                                  2           2                3    1
# 89998                                  2           3                1    6
# 89999                                  3           2                3    4
#
#        Type of Admission  Severity of Illness  health_conditions  Insurance
# 0                    1.0                  1.0                  5          0
# 1                    1.0                  1.0                  0          1
# 2                    1.0                  1.0                  4          0
# 3                    1.0                  1.0                  4          1
# 4                    1.0                  2.0                  1          0
# ...                  ...                  ...                ...        ...
# 89995                1.0                  0.0                  3          0
# 89996                2.0                  1.0                  5          0
# 89997                2.0                  1.0                  3          0
# 89998                1.0                  2.0                  1          0
# 89999                1.0                  1.0                  2          1
#
# [90000 rows x 8 columns]

# %% [markdown]
# ## Modelo de Clasificación de Machine Learning: Árbol de Decisión

# %% [markdown]
# #### Importamos las librerías para nuestro modelo y las métricas a usar.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import recall_score

# %%
# Declaramos las variables para nuestro modelo. En este caso he dado prioridad al recall. 
# Descarto "Insurance" por tener una correlación demasiado baja con la variable de salida.

X = DF2.drop(["Stay (in days)", "length of stay", "Insurance"], axis=1)    
y = DF2["length of stay"]

# %%
X
# Out:
#         Available Extra Rooms in Hospital  Department  staff_available  Age  \
# 0                                       4           2                0    4
# 1                                       4           2                2    3
# 2                                       2           2                8    2
# 3                                       4           2                7    3
# 4                                       2           1               10    7
# ...                                   ...         ...              ...  ...
# 409995                                  1           2                1    3
# 409996                                  5           2                5    2
# 409997                                  4           2                9    2
# 409998                                 10           2               10    2
# 409999                                  3           2                0    4
#
#         Type of Admission  Severity of Illness  health_conditions
# 0                     1.0                  2.0                  1
# 1                     1.0                  0.0                  2
# 2                     1.0                  2.0                  1
# 3                     0.0                  1.0                  4
# 4                     1.0                  1.0                  1
# ...                   ...                  ...                ...
# 409995                1.0                  0.0                  0
# 409996                1.0                  2.0                  5
# 409997                2.0                  0.0                  0
# 409998                1.0                  1.0                  5
# 409999                1.0                  0.0                  5
#
# [410000 rows x 7 columns]

# %%
# Separamos los datos en Entrenamiento y Testeo. Un paso necesario previo al entrenamiento del modelo.

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
#Observamos la forma de los datos 
X_train.shape, X_test.shape
# Out:
# ((328000, 5), (82000, 5))

# %%
# Se define el clasificador
dt = DecisionTreeClassifier(max_depth=14)

# Se entrena el modelo
dt.fit(X_train, y_train)

# Predicciones
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# Desempeño del modelo entrenado, calculando la precisión (accuracy)
dt_train_accuracy = accuracy_score(y_train, y_train_pred)

# Desempeño del modelo testeado, calculando la precisión (accuracy)
dt_test_accuracy = accuracy_score(y_test, y_test_pred)

print('Desempeño del modelo para el Training set: ',dt_train_accuracy)
print('Desempeño del modelo para el Test set: ',dt_test_accuracy)
# Out:
# Desempeño del modelo para el Training set:  0.7055670731707318
# Desempeño del modelo para el Test set:  0.6998292682926829

# %%
cfd = ConfusionMatrixDisplay(confusion_matrix(y_test,y_test_pred,labels=[0,1]))

# %%
# Desempeño del modelo en test, calculando el recall

recall = recall_score(y_test, y_test_pred, average= None)
recall
# Out:
# array([0.43755862, 0.85856351])

# %% [markdown]
# #### Ingestamos los datos del CSV de testeo en el modelo de árbol de decisión, ya entrenado con el dataset donde teniamos datos de salida. Ya que este es un modelo de aprendizaje supervisado.

# %%
XT = DFT2.drop(["Insurance"], axis=1) 
pred = dt.predict(XT)

# %% [markdown]
# #### Agrego una fila al dataframe de testeo que será donde vaya su predicción.

# %%
DFT2["pred"]= pred

# %%
DFT2
# Out:
#        Available Extra Rooms in Hospital  Department  staff_available  Age  \
# 0                                      3           2               10    2
# 1                                      2           0                4    5
# 2                                      2           3                7    5
# 3                                      2           2                1    2
# 4                                      2           1                7    5
# ...                                  ...         ...              ...  ...
# 89995                                  4           2                2    1
# 89996                                 13           2                8    3
# 89997                                  2           2                3    1
# 89998                                  2           3                1    6
# 89999                                  3           2                3    4
#
#        Type of Admission  Severity of Illness  health_conditions  Insurance  \
# 0                    1.0                  1.0                  5          0
# 1                    1.0                  1.0                  0          1
# 2                    1.0                  1.0                  4          0
# 3                    1.0                  1.0                  4          1
# 4                    1.0                  2.0                  1          0
# ...                  ...                  ...                ...        ...
# 89995                1.0                  0.0                  3          0
# 89996                2.0                  1.0                  5          0
# 89997                2.0                  1.0                  3          0
# 89998                1.0                  2.0                  1          0
# 89999                1.0                  1.0                  2          1
#
#       pred
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 89995    1
# 89996    1
# 89997    1
# 89998    1
# 89999    1
#
# [90000 rows x 9 columns]

# %% [markdown]
# #### Convertimos la columna de predicción en un dataframe para poder convertirlo a CSV.

# %%
#Transformo la columna que predijo el modelo a Dataframe

Predicción = pd.DataFrame(DFT2["pred"])

#Finalmente guardo este Dataframe como CSV

ruta = "D:/Melissa/Modelo-Machine Learning/MelissaContreras.csv"

Predicción.to_csv(ruta,index=False, encoding='utf-8-sig')
